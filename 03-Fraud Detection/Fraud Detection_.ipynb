# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#DDDDDD  ; font-size:150%; text-align:center; border-radius:10px 10px;">WELCOME!<p>

# %% [markdown]
# Welcome to "***Fraud Detection Project***". This is the last project of the Capstone Series.
#
# One of the challenges in this project is the absence of domain knowledge. So without knowing what the column names are, you will only be interested in their values. The other one is the class frequencies of the target variable are quite imbalanced.
#
# You will implement ***Logistic Regression, Random Forest, XGBoost,and Neural Network*** algorithms and ***Unbalanced Data Techniques*** . Also visualize performances of the models using ***Seaborn, Matplotlib*** and ***Yellowbrick*** in a variety of ways.
#
# Data drift and model drirft are key consepts about ML and MLOPS, you can monitor and check your data and models with plenty of ways and tools. ***Deepchecks*** is one of them and the leading tool for testing and for validating your machine learning models and data, and it enables doing so with minimal effort. In this project, you will apply ***Data Integrity, Train-Test Validation, and Model Evaluation*** checks.
# Deepchecks Intruduction : https://youtu.be/7ELdizoi6BU
#
# At the end of the project, you will have the opportunity to deploy your model by ***Streamlit API***.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with model deployement (Streamlit) as well as the theory behind algorithms*

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Determines
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where it has **492 frauds** out of **284,807** transactions. The dataset is **highly unbalanced**, the positive class (frauds) account for 0.172% of all transactions.
#
# **Feature Information:**
#
# **Time**: This feature is contains the seconds elapsed between each transaction and the first transaction in the dataset.
#
# **Amount**:  This feature is the transaction Amount, can be used for example-dependant cost-senstive learning.
#
# **Class**: This feature is the target variable and it takes value 1 in case of fraud and 0 otherwise.
#
# ---
#
# The aim of this project is to predict whether a credit card transaction is fraudulent. Of course, this is not easy to do.
# First of all, you need to analyze and recognize your data well in order to draw your roadmap and choose the correct arguments you will use. Accordingly, you can examine the frequency distributions of variables. You can observe variable correlations and want to explore multicollinearity. You can display the distribution of the target variable's classes over other variables.
# Also, it is useful to take missing values and outliers.
#
# After these procedures, you can move on to the model building stage by doing the basic data pre-processing you are familiar with.
#
# Start with Logistic Regression and evaluate model performance. You will apply the Unbalanced Data Techniques used to increase the performance. Next, observe their effects.
#
# Then, you will use four different algorithms in the model building phase.
#
# In the final step, you will deploy your model using ***Streamlit API***.
#
# **Optional**: You can Dockerize your project and deploy on cloud.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Tasks
#
# #### 1. Exploratory Data Analysis & Data Cleaning
#
# - Import Modules, Load Data & Data Review
# - Apply data integrity checks
# - Exploratory Data Analysis
# - Data Cleaning
#
# #### 2. Data Preprocessing
#
# - Train - Test Split
# - Train - Test Split Validation Checks
# - Scaling
#
# #### 3. Model Building
#
# - Logistic Regression
# - Random Forest Classifier
# - XGBoost Classifier
# - Neural Network
# -
#
# #### 4. Model Deployement
#
# - Save and Export the Best Model
# - Save and Export Variables

# %% [markdown]
# ---
# ---

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#DDDDDD  ; font-size:125%; text-align:center; border-radius:10px 10px;">Import Modules, Load Data & Data Review<p>

# %% [markdown]
# ## Import Libraies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## feature Selection
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif, f_regression, mutual_info_regression

## pre-processing
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline
# from sklearn.cluster import KMeans, AgglomerativeClustering
# from sklearn.decomposition import PCA
# from sklearn.dummy import DummyClassifier
# from sklearn.impute import SimpleImputer, KNNImputer

## scaling
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler

## metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve
from sklearn.metrics import  roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.metrics import silhouette_samples,silhouette_score, average_precision_score
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import auc

# Colab-Error
# from sklearn.metrics import plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve,
# from scikitplot.metrics import plot_roc

## model selection
# from sklearn import model_selection
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.model_selection import RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, cross_val_predict

## Model Building
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree 
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier
from xgboost import XGBClassifier, plot_importance

## ann
import tensorflow as tf
from sklearn.neural_network import MLPRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, Nadam, SGD, Adamax, RMSprop,Adadelta, Adagrad
from tensorflow.keras.layers import Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# from scikeras.wrappers import KerasClassifier, KerasRegressor
# from sikeras.callbacks import EarlyStopping

from sklearn.utils import class_weight
from sklearn.utils import compute_class_weight

# pip install livelossplot
from livelossplot import PlotLossesKerasTF

## YellowBrick
from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.classifier import ClassPredictionError

## SMOTE
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as impipeline

# Deployment
import pickle
from tensorflow.keras.models import load_model

plt.rcParams["figure.figsize"] = (12,8)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## User defined functions

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)

    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
def train_val(y_train, y_train_pred, y_test, y_pred):
    
    scores = {"train_set": {"Accuracy" : accuracy_score(y_train, y_train_pred),
                            "Precision" : precision_score(y_train, y_train_pred),
                            "Recall" : recall_score(y_train, y_train_pred),                          
                            "f1" : f1_score(y_train, y_train_pred),
                            "roc_auc" : roc_auc_score(y_train, y_train_pred),
                            "recall_auc" : auc(recall, precision)},
    
              "test_set": {"Accuracy" : accuracy_score(y_test, y_pred),
                           "Precision" : precision_score(y_test, y_pred),
                           "Recall" : recall_score(y_test, y_pred),                          
                           "f1" : f1_score(y_test, y_pred),
                           "roc_auc" : roc_auc_score(y_test, y_pred),
                           "recall_auc" : auc(recall, precision)}}
    
    return pd.DataFrame(scores)

# %% [markdown]
# ## Loading & Reading the Data

# %%
df = pd.read_csv("creditcard.csv")
df.sample(7)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 123133   76823.0 -0.278259  0.921802  1.842804  0.847927 -1.678244  0.151934
# 249241  154309.0 -1.082155  0.607648  0.523952 -1.075256  0.845547 -0.592784
# 90976    63261.0 -1.384063  0.449733 -0.979610  0.213833  1.722941  3.807883
# 137222   82070.0  1.121773 -0.123515  0.019074  0.024665 -0.412840 -0.984146
# 218310  141261.0 -1.193301  0.795799  1.412847 -0.715361  0.769098  0.035129
# 41431    40678.0 -1.948438  1.154817  0.691071 -0.295049  1.035772  1.627299
# 139298   83093.0  1.003421  0.193060  1.620985  2.690939 -0.543496  0.913447
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 123133 -1.770965 -3.111709  0.525542  0.129582  0.203313  0.776336  0.734562
# 249241  1.336762  0.015611 -0.244325 -1.954945  0.662552  0.092885 -0.907507
# 90976  -0.682824  1.771311 -0.358787 -0.680977 -1.065415  0.303622 -0.037661
# ...

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#DDDDDD  ; font-size:125%; text-align:center; border-radius:10px 10px;">Exploratory Data Analysis<p>

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.duplicated().sum() , df.isna().sum().sum()
# Out:
# (1081, 0)

# %%
len(df[(df.duplicated() == 1) & (df["Class"] == 1)])
# Out:
# 19

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Apply Data Integrity Checks
# * link: https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_data_integrity.html

# %%
#pip install deepchecks

# %%
import sys
from deepchecks.tabular import datasets
from deepchecks.tabular import Dataset
from deepchecks.tabular.suites import data_integrity

# %%
data = datasets.regression.avocado.load_data(
    data_format='DataFrame', as_train_test=False)

# %%
ds = Dataset(df, cat_features=[],
             datetime_name='Time', label='Class')

# %%
# Run Suite:
integ_suite = data_integrity()
suite_result = integ_suite.run(ds)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result.show()
# Out:
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_S045H5DQB7BZNWG2O6ORE9825">Data Integrity Sui…

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# ## Features and Data Insights

# %% [markdown]
# ### *Class*

# %%
df["Class"].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.countplot(data=df, x="Class")
ax.bar_label(ax.containers[0], fontsize=14, color='black', fontweight='bold');

# %%
plt.figure(figsize=(10,10))
plt.pie(df["Class"].value_counts(), labels=["Fraud", "Nofraud"], autopct='%0.2f%%', radius=1.2, textprops={'color':'black','fontsize': 20});

# %% [markdown]
# ### *Amount*

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.boxplot(data=df, x="Amount")

# %%
sns.relplot(data=df, x="Amount", y="Class", hue="Class", size="Amount");

# %% [markdown]
# ### *Time*

# %%
df["Time"].head(7)
# Out:
# 0    0.0
# 1    0.0
# 2    1.0
# 3    1.0
# 4    2.0
# 5    2.0
# 6    4.0
# Name: Time, dtype: float64

# %%
df["Time"].tail(7)
# Out:
# 284800    172784.0
# 284801    172785.0
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, dtype: float64

# %%
172792/60/60/24
# Out:
# 1.9999074074074075

# %%
sns.relplot(data=df, x="Time", y="Amount", hue="Class");

# %%
sns.scatterplot(data=df, x="Time", y="Class", hue="Class");

# %%
# Not: Dolandırıcılık yoğunluğu histogram çizilecek

# %%
## Histograms
fig = plt.figure(figsize=(15, 20))
plt.suptitle('Histograms of Numerical Columns', fontsize=20)
for i in range(df.shape[1]):
    plt.subplot(8, 4, i+1)
    f = plt.gca()
    f.set_title(df.columns.values[i])                                     
    sns.histplot(df.iloc[:, i])
    
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# ## *Correlations*

# %%
plt.figure(figsize=(25, 14))
sns.heatmap(df.drop('Class',1).corr(), annot=True, cmap='viridis', linewidth=1, linecolor='black', fmt='.2f')
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_23060\1306032420.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.heatmap(df.drop('Class',1).corr(), annot=True, cmap='viridis', linewidth=1, linecolor='black', fmt='.2f')
# <AxesSubplot:>

# %%
plt.figure(figsize=(14, 8))
df.corr()['Class'].drop('Class').sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# SAMPLES
fig, ax = plt.subplots(4,2, figsize=(16,12))
sns.scatterplot(x=df.V11,y=df.V17, hue=df.Class, ax=ax[0,0])
sns.scatterplot(x=df.V4,y=df.V14, hue=df.Class, ax=ax[0,1])
sns.scatterplot(x=df.V2,y=df.V12, hue=df.Class, ax=ax[1,0])
sns.scatterplot(x=df.V10,y=df.V16, hue=df.Class, ax=ax[1,1])
sns.scatterplot(x=df.V3,y=df.V7, hue=df.Class, ax=ax[2,0])
sns.scatterplot(x=df.V15,y=df.V22, hue=df.Class, ax=ax[2,1])
sns.scatterplot(x=df.V11,y=df.Amount, hue=df.Class, ax=ax[3,0])
sns.scatterplot(x=df.V17,y=df.Amount, hue=df.Class, ax=ax[3,1]);

# %% [markdown]
# ### Data Cleaning
# Check Missing Values and Outliers

# %%
plt.figure(figsize=(24, 16))
index = 0
for boxplot in df.drop('Class',axis=1).select_dtypes('number').columns:
    index += 1
    plt.subplot(6,5,index)
    sns.boxplot(x = boxplot, data=df)
plt.tight_layout();

# %%
iqr_factor = [1.5, 2]
list1, list2 = [], []

for factor in iqr_factor:
    count = 0
    print(f'Outliers for {factor} IQR :')
    print('-------------------------------------')
    for col in df.select_dtypes(['int64', 'float64']):
    
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        lower_lim = df[col].quantile(0.25) - factor*IQR
        upper_lim = df[col].quantile(0.75) + factor*IQR
    
        cond = df[(df[col] < lower_lim) | (df[col] > upper_lim)].shape[0]
        
        if cond > 0 and factor == 1.5:
            list1.append(df[(df[col] < lower_lim) | (df[col] > upper_lim)].index.tolist())
        elif cond > 0 and factor == 2:
            list2.append(df[(df[col] < lower_lim) | (df[col] > upper_lim)].index.tolist())
        
        if cond > 0: print(f'{col:<10} : ', cond); count += cond
    print(f'\nTOTAL OUTLIERS FOR {factor} IQR : {count}')
    print('')
# Out:
# Outliers for 1.5 IQR :
# -------------------------------------
# V1         :  6948
# V2         :  13390
# V3         :  3306
# V4         :  11094
# V5         :  12221
# V6         :  22886
# V7         :  8839
# V8         :  23904
# V9         :  8199
# V10        :  9345
# V11        :  735
# V12        :  15282
# V13        :  3362
# V14        :  14060
# V15        :  2884
# V16        :  8180
# V17        :  7353
# V18        :  7468
# V19        :  10150
# V20        :  27553
# V21        :  14401
# V22        :  1298
# V23        :  18467
# V24        :  4758
# V25        :  5333
# V26        :  5665
# V27        :  38799
# V28        :  30094
# Amount     :  31685
# Class      :  473
#
# TOTAL OUTLIERS FOR 1.5 IQR : 368132
#
# Outliers for 2 IQR :
# -------------------------------------
# V1         :  4342
# V2         :  8872
# V3         :  1764
# V4         :  4750
# V5         :  5985
# V6         :  18954
# V7         :  5725
# V8         :  17099
# ...

# %%
df2 = df.copy()

# %%
df_Fraud = df2[df2["Class"] == 1]

# %%
df_Fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9       V10       V11        V12       V13  \
# 541  -2.537387  1.391657 -2.770089 -2.772272  3.202033  -2.899907 -0.595222
# 623   0.325574 -0.067794 -0.270953 -0.838587 -0.414575  -0.503141  0.676502
# 4920  0.562320 -0.399147 -0.238253 -1.525412  2.032912  -6.560124  0.022937
# 6108 -3.496197 -0.248778 -0.247768 -4.801637  4.895844 -10.912819  0.184372
# 6329  1.713445 -0.496358 -1.282858 -2.447469  2.101344  -4.609628  1.464378
#
# ...

# %%
df_No_Fraud = df2[df2["Class"] == 0]

# %%
df_No_Fraud
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
columns = df_No_Fraud.drop("Class", axis=1)
for i in columns:
    q1 = df_No_Fraud[i].quantile(0.25)
    q3 = df_No_Fraud[i].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_No_Fraud = df_No_Fraud.loc[(df_No_Fraud[i] > fence_low) & (df_No_Fraud[i] < fence_high)]

# %%
df_No_Fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 5            2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6            4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 9            9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 12          10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...          ...       ...       ...       ...       ...       ...       ...
# 284794  172777.0 -1.266580 -0.400461  0.956221 -0.723919  1.531993 -1.788600
# 284796  172780.0  1.884849 -0.143540 -0.999943  1.506772 -0.035300 -0.613638
# 284797  172782.0 -0.241923  0.712247  0.399806 -0.463406  0.244531 -1.343668
# 284800  172784.0  2.039560 -0.175233 -1.196825  0.234580 -0.008713 -0.726571
# 284801  172785.0  0.120316  0.931005 -0.546012 -0.745097  1.130314 -0.235973
#
# ...

# %%
df_Fraud.shape
# Out:
# (473, 31)

# %%
df2 = pd.concat([df_Fraud, df_No_Fraud])

# %%
df2 = df2.sample(frac=1).reset_index(drop=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110279 entries, 0 to 110278
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    110279 non-null  float64
#  1   V1      110279 non-null  float64
#  2   V2      110279 non-null  float64
#  3   V3      110279 non-null  float64
#  4   V4      110279 non-null  float64
#  5   V5      110279 non-null  float64
#  6   V6      110279 non-null  float64
#  7   V7      110279 non-null  float64
#  8   V8      110279 non-null  float64
#  9   V9      110279 non-null  float64
#  10  V10     110279 non-null  float64
#  11  V11     110279 non-null  float64
#  12  V12     110279 non-null  float64
#  13  V13     110279 non-null  float64
#  14  V14     110279 non-null  float64
#  15  V15     110279 non-null  float64
#  16  V16     110279 non-null  float64
#  17  V17     110279 non-null  float64
#  18  V18     110279 non-null  float64
#  19  V19     110279 non-null  float64
# ...

# %%
df2["Class"].value_counts()
# Out:
# 0    109806
# 1       473
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(24, 16))
index = 0
for boxplot in df2.drop('Class',axis=1).select_dtypes('number').columns:
    index += 1
    plt.subplot(6,5,index)
    sns.boxplot(x = boxplot, data=df2)
plt.tight_layout();

# %%
# df2.to_csv("clean_df_without_outlier.csv", index=False)

# %%
# df.to_csv("clean_df_with_outlier.csv", index=False)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#DDDDDD  ; font-size:125%; text-align:center; border-radius:10px 10px;">Data Preprocessing<p>

# %% [markdown]
# #### Train - Test Split
#
# As in this case, for extremely imbalanced datasets you may want to make sure that classes are balanced across train and test data.

# %%
df = pd.read_csv("clean_df_without_outlier.csv")
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 70230   165034.0  1.993606 -0.639655 -0.512795  0.225015 -0.579832  0.177418
# 95604   135773.0  1.967229 -0.496240 -0.996697  0.023761  0.011727  0.210800
# 61795   130079.0  2.073623 -0.057580 -1.127328  0.382083 -0.077861 -1.131416
# 103041  164576.0  2.017723 -0.682314 -0.746127 -1.632307 -0.607296 -0.545460
# 3832     76819.0  1.238657 -0.653428  0.604873 -1.159236 -1.335605 -0.962766
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 70230  -0.909253  0.259829  1.321015  0.223157 -0.187577 -0.106207 -1.572180
# 95604  -0.443329  0.055179  1.408051 -0.251781 -1.760050 -0.034633  0.045727
# 61795   0.176098 -0.321429  0.562398  0.075826 -0.885122  0.352341  0.019158
# 103041 -0.571078  0.015894  1.791769 -0.802711  1.201605  1.675716  0.314587
# 3832   -0.570381 -0.035425  2.123796 -1.166313 -0.733294  0.170075 -1.235141
#
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone/Fraud Detection/clean_df_without_outlier.csv")
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 108134  157351.0  2.040454 -0.037511 -1.431320  0.145192  0.286067 -0.639137
# 52882   112803.0 -0.238279  0.831746  0.048584 -0.821261  0.595320 -0.502690
# 43390    43314.0  0.980919 -0.350761  0.863512  1.434272 -0.830522  0.117932
# 52102    34779.0  1.155594 -0.529207  1.104154  0.202021 -1.380181 -0.483989
# 34573    33683.0 -0.509195  0.003879  2.008143 -0.732899 -0.791466 -0.099419
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 108134  0.113688 -0.178613  0.286976  0.170200  1.056799  1.079467  0.227837
# 52882   0.818084 -0.035770 -0.013239 -0.005232  0.337491  0.262774 -0.847974
# 43390  -0.365380  0.199413  0.784526 -0.110450  0.508849  0.894193 -1.022780
# 52102  -0.742067  0.112310  1.294203 -0.363354 -0.877288 -0.265908 -1.286658
# 34573  -0.697751  0.059086 -0.974033  0.638592 -0.141666 -0.808295  0.488648
#
# ...

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.15, random_state=42)

# %%
print('X_train.shape:', X_train.shape)
print('y_train.shape:', y_train.shape)
print('X_test.shape:', X_test.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (93737, 30)
# y_train.shape: (93737,)
# X_test.shape: (16542, 30)
# y_test.shape: (16542,)

# %% [markdown]
# ## Train-Test Validation Checks
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_train_test_validation.html

# %%
train_ds = Dataset(X_train, cat_features=[])
test_ds = Dataset(X_test, cat_features=[])

# %%
from deepchecks.tabular.suites import train_test_validation

validation_suite = train_test_validation()
suite_result = validation_suite.run(train_ds, test_ds)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result
# Out:
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_GMA9PBKEFT27TTCHT3P8D6XIZ">Train Test Validat…

# %% [markdown]
# ---
# ---

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#191A19  ; font-size:125%; text-align:center; border-radius:10px 10px;">Logistic Regression without SMOTE<p>

# %% [markdown]
# ## ***Vanilla Logistic Model***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
scaler = StandardScaler()
LogReg = LogisticRegression(class_weight = 'balanced', random_state = 42, max_iter=1000)
log_model = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,LogReg)])
log_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('StandardScaler', StandardScaler()),
#                 ('LogReg',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
eval_metric(log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[16350   121]
#  [    5    66]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     16471
#            1       0.35      0.93      0.51        71
#
#     accuracy                           0.99     16542
#    macro avg       0.68      0.96      0.75     16542
# weighted avg       1.00      0.99      0.99     16542
#
#
# Train_Set
# [[92604   731]
#  [    8   394]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     93335
#            1       0.35      0.98      0.52       402
#
#     accuracy                           0.99     93737
#    macro avg       0.68      0.99      0.76     93737
# weighted avg       1.00      0.99      0.99     93737

# %%
plt.figure(figsize=(10,6))

y_pred = log_model.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
scaler = StandardScaler()
log_model = LogisticRegression(class_weight = "balanced",
                                  random_state = 42,
                                  max_iter=1000)

log_model = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,log_model)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(log_model, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Cross Validation*

# %%
scaler = StandardScaler()
LogReg = LogisticRegression(class_weight = 'balanced', random_state = 42, max_iter=1000)
log_model = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,LogReg)])
kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(log_model, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.991498
# train_accuracy     0.991616
# test_precision     0.335402
# train_precision    0.337704
# test_recall        0.960122
# train_recall       0.979822
# test_f1            0.495626
# train_f1           0.501864
# test_roc_auc       0.988996
# train_roc_auc      0.997535
# dtype: float64

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = log_model.predict(X_test)
y_train_pred = log_model.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


log_model_f1 = f1_score(y_test, y_pred)
log_model_acc = accuracy_score(y_test, y_pred)
log_model_recall = recall_score(y_test, y_pred)
log_model_auc = roc_auc_score(y_test, y_pred)
log_model_pre = precision_score(y_test, y_pred)
log_model_recall_auc = auc(recall, precision)

# %%
train_val_log = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_log
# Out:
#             train_set  test_set
# Accuracy     0.992116  0.992383
# Precision    0.350222  0.352941
# Recall       0.980100  0.929577
# f1           0.516045  0.511628
# roc_auc      0.986134  0.961116
# recall_auc   0.641410  0.641410

# %% [markdown]
# ## ***Tuned Logistic Model***

# %% [markdown]
# ### *GridSearch*

# %%
log_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('StandardScaler', StandardScaler()),
#   ('LogReg',
#    LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42))],
#  'verbose': False,
#  'StandardScaler': StandardScaler(),
#  'LogReg': LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42),
#  'StandardScaler__copy': True,
#  'StandardScaler__with_mean': True,
#  'StandardScaler__with_std': True,
#  'LogReg__C': 1.0,
#  'LogReg__class_weight': 'balanced',
#  'LogReg__dual': False,
#  'LogReg__fit_intercept': True,
#  'LogReg__intercept_scaling': 1,
#  'LogReg__l1_ratio': None,
#  'LogReg__max_iter': 1000,
#  'LogReg__multi_class': 'auto',
#  'LogReg__n_jobs': None,
#  'LogReg__penalty': 'l2',
#  'LogReg__random_state': 42,
#  'LogReg__solver': 'lbfgs',
#  'LogReg__tol': 0.0001,
#  'LogReg__verbose': 0,
#  'LogReg__warm_start': False}

# %%
param_grid = {"LogReg__C": [0.5, 1],
              'LogReg__penalty': ["l1","l2"],
              'LogReg__solver' : ['liblinear', 'lbfgs']}

# %%
scaler = StandardScaler()
LogReg = LogisticRegression(class_weight = 'balanced', random_state = 42, max_iter=1000)
log_model = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,LogReg)])
kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

log_model_grid = GridSearchCV(log_model,
                              param_grid,
                              verbose=3,
                              scoring="recall",
                              cv=kfold,
                              n_jobs=-1,
                              return_train_score=True)

# %%
log_model_grid.fit(X_train, y_train)

# %%
print('Best Params :', log_model_grid.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', log_model_grid.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
scaler = StandardScaler()
clf_grid = LogisticRegression(class_weight = "balanced",
                                  penalty = 'l2', 
                                  solver = 'lbfgs',
                                  random_state = 42,
                                  max_iter=1000)
log_model_grid = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,clf_grid)])
log_model_grid.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('StandardScaler', StandardScaler()),
#                 ('LogReg',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[16350   121]
#  [    5    66]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     16471
#            1       0.35      0.93      0.51        71
#
#     accuracy                           0.99     16542
#    macro avg       0.68      0.96      0.75     16542
# weighted avg       1.00      0.99      0.99     16542
#
#
# Train_Set
# [[92604   731]
#  [    8   394]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     93335
#            1       0.35      0.98      0.52       402
#
#     accuracy                           0.99     93737
#    macro avg       0.68      0.99      0.76     93737
# weighted avg       1.00      0.99      0.99     93737

# %%
plt.figure(figsize=(10,6))

y_pred = log_model_grid.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
scaler = StandardScaler()
clf_grid = LogisticRegression(class_weight = "balanced",
                                  penalty = 'l2', 
                                  solver = 'lbfgs',
                                  random_state = 42,
                                  max_iter=1000)
log_model_grid = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,clf_grid)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(log_model_grid, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = log_model_grid.predict(X_test)
y_train_pred = log_model_grid.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


log_model_grid_f1 = f1_score(y_test, y_pred)
log_model_grid_acc = accuracy_score(y_test, y_pred)
log_model_grid_recall = recall_score(y_test, y_pred)
log_model_grid_auc = roc_auc_score(y_test, y_pred)
log_model_grid_pre = precision_score(y_test, y_pred)
log_model_grid_recall_auc = auc(recall, precision)

# %%
train_val_log_grid = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_log_grid
# Out:
#             train_set  test_set
# Accuracy     0.992116  0.992383
# Precision    0.350222  0.352941
# Recall       0.980100  0.929577
# f1           0.516045  0.511628
# roc_auc      0.986134  0.961116
# recall_auc   0.641410  0.641410

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#191A19 ;font-weight: normal; font-size:125%; text-align:center; border-radius:10px 10px;">Logistic Regression with SMOTE<p>

# %% [markdown]
# ## ***Vanilla Logistic Model with Smote***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
X = df.drop(['Class'], axis = 1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y,
                                                     test_size = 0.2, random_state = 42)

# %%
print('X_train.shape : ', X_train.shape)
print('X_test.shape  : ', X_test.shape)
print('X_test.shape  : ', y_train.shape)
print('X_test.shape  : ', y_test.shape)
# Out:
# X_train.shape :  (88223, 30)
# X_test.shape  :  (22056, 30)
# X_test.shape  :  (88223,)
# X_test.shape  :  (22056,)

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

LogReg = LogisticRegression(random_state = 42, max_iter=1000)

log_model_smote = impipeline(steps=[("StandardScaler", scaler), 
                                  ('o', over), ('u', under),
                                  ("LogReg" ,LogReg)])
log_model_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('StandardScaler', StandardScaler()),
#                 ('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('LogReg', LogisticRegression(max_iter=1000, random_state=42))])

# %%
eval_metric(log_model_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21888    73]
#  [    8    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       0.54      0.92      0.68        95
#
#     accuracy                           1.00     22056
#    macro avg       0.77      0.96      0.84     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87540   305]
#  [   11   367]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       0.55      0.97      0.70       378
#
#     accuracy                           1.00     88223
#    macro avg       0.77      0.98      0.85     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = log_model_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

LogReg = LogisticRegression(random_state = 42, max_iter=1000)

log_model_smote = impipeline(steps=[("StandardScaler", scaler), 
                                  ('o', over), ('u', under),
                                  ("LogReg" ,LogReg)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(log_model_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = log_model_smote.predict(X_test)
y_train_pred = log_model_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


log_model_smote_f1 = f1_score(y_test, y_pred)
log_model_smote_acc = accuracy_score(y_test, y_pred)
log_model_smote_recall = recall_score(y_test, y_pred)
log_model_smote_auc = roc_auc_score(y_test, y_pred)
log_model_smote_pre = precision_score(y_test, y_pred)
log_model_smote_recall_auc = auc(recall, precision)

# %%
train_val_log_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_log_smote
# Out:
#             train_set  test_set
# Accuracy     0.996679  0.996872
# Precision    0.565485  0.587838
# Recall       0.970899  0.915789
# f1           0.714703  0.716049
# roc_auc      0.983845  0.956506
# recall_auc   0.751995  0.751995

# %% [markdown]
# ### *Cross Validation*

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
LogReg = LogisticRegression(random_state = 42, max_iter=1000)

log_model_smote = impipeline(steps=[("StandardScaler", scaler), 
                                  ('o', over), ('u', under),
                                  ("LogReg" ,LogReg)])

kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(log_model_smote, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.996758
# train_accuracy     0.996788
# test_precision     0.579582
# train_precision    0.576145
# test_recall        0.949787
# train_recall       0.968548
# test_f1            0.718269
# train_f1           0.721935
# test_roc_auc       0.988669
# train_roc_auc      0.997751
# dtype: float64

# %% [markdown]
# ## ***Tuned Logistic Model with Smote***

# %% [markdown]
# ### *GridSearch*

# %%
log_model_smote.get_params()
# Out:
# {'memory': None,
#  'steps': [('StandardScaler', StandardScaler()),
#   ('o', SMOTE(sampling_strategy={1: 10000})),
#   ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#   ('LogReg', LogisticRegression(max_iter=1000, random_state=42))],
#  'verbose': False,
#  'StandardScaler': StandardScaler(),
#  'o': SMOTE(sampling_strategy={1: 10000}),
#  'u': RandomUnderSampler(sampling_strategy={0: 30000}),
#  'LogReg': LogisticRegression(max_iter=1000, random_state=42),
#  'StandardScaler__copy': True,
#  'StandardScaler__with_mean': True,
#  'StandardScaler__with_std': True,
#  'o__k_neighbors': 5,
#  'o__n_jobs': None,
#  'o__random_state': None,
#  'o__sampling_strategy': {1: 10000},
#  'u__random_state': None,
#  'u__replacement': False,
#  'u__sampling_strategy': {0: 30000},
#  'LogReg__C': 1.0,
#  'LogReg__class_weight': None,
#  'LogReg__dual': False,
#  'LogReg__fit_intercept': True,
#  'LogReg__intercept_scaling': 1,
#  'LogReg__l1_ratio': None,
#  'LogReg__max_iter': 1000,
# ...

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
LogReg = LogisticRegression(random_state = 42, max_iter=1000)
log_model_grid_smote = impipeline(steps=[("StandardScaler", scaler), 
                                  ('o', over), ('u', under),
                                  ("LogReg" ,LogReg)])

param_grid = {"LogReg__C": [0.5, 1],
              'LogReg__penalty': ["l1","l2"],
              'LogReg__solver' : ['liblinear', 'lbfgs']}

kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

log_model_grid_smote = GridSearchCV(log_model_grid_smote,
                              param_grid,
                              verbose=3,
                              scoring="recall",
                              cv=kfold,
                              n_jobs=-1,
                              return_train_score=True)

# %%
log_model_grid_smote.fit(X_train, y_train)

# %%
print('Best Params :', log_model_grid_smote.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', log_model_grid_smote.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
clf_grid_smote = LogisticRegression(solver = 'lbfgs',
                                    penalty = 'l2', 
                                    random_state = 42,
                                    max_iter=1000)

log_model_grid_smote = impipeline(steps=[("StandardScaler", scaler), 
                                    ('o', over), ('u', under),
                                    ("LogReg" ,clf_grid_smote)])


log_model_grid_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('StandardScaler', StandardScaler()),
#                 ('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('LogReg', LogisticRegression(max_iter=1000, random_state=42))])

# %%
eval_metric(log_model_grid_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21897    64]
#  [    8    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       0.58      0.92      0.71        95
#
#     accuracy                           1.00     22056
#    macro avg       0.79      0.96      0.85     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87572   273]
#  [   11   367]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       0.57      0.97      0.72       378
#
#     accuracy                           1.00     88223
#    macro avg       0.79      0.98      0.86     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(14,8))

y_pred = log_model_grid_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
scaler = StandardScaler()
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
clf_grid_smote = LogisticRegression(solver = 'lbfgs',
                                    penalty = 'l2', 
                                    random_state = 42,
                                    max_iter=1000)

log_model_grid_smote = impipeline(steps=[("StandardScaler", scaler), 
                                    ('o', over), ('u', under),
                                    ("LogReg" ,clf_grid_smote)])
plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(log_model_grid_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = log_model_grid_smote.predict(X_test)
y_train_pred = log_model_grid_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


log_model_grid_smote_f1 = f1_score(y_test, y_pred)
log_model_grid_smote_acc = accuracy_score(y_test, y_pred)
log_model_grid_smote_recall = recall_score(y_test, y_pred)
log_model_grid_smote_auc = roc_auc_score(y_test, y_pred)
log_model_grid_smote_pre = precision_score(y_test, y_pred)
log_model_grid_smote_recall_auc = auc(recall, precision)

# %%
train_val_log_grid_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_log_grid_smote
# Out:
#             train_set  test_set
# Accuracy     0.996849  0.996781
# Precision    0.579365  0.580000
# Recall       0.965608  0.915789
# f1           0.724206  0.710204
# roc_auc      0.981296  0.956460
# recall_auc   0.748076  0.748076

# %% [markdown]
# # <p style="background-color:#367E18   ;font-family:newtimeroman; font-weight: normal; color:#191A19 ; font-size:125%; text-align:center; border-radius:10px 10px;">Random Forest Classifier without SMOTE<p>

# %% [markdown]
# ## ***Vanilla RF Model***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
rf_model = RandomForestClassifier( class_weight="balanced", random_state = 42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
eval_metric(rf_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21961     0]
#  [   11    84]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       1.00      0.88      0.94        95
#
#     accuracy                           1.00     22056
#    macro avg       1.00      0.94      0.97     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [    0   378]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      1.00      1.00       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      1.00      1.00     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = rf_model.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
rf_model = RandomForestClassifier( class_weight="balanced", random_state = 42)

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(rf_model, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = rf_model.predict(X_test)
y_train_pred = rf_model.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


rf_model_f1 = f1_score(y_test, y_pred)
rf_model_acc = accuracy_score(y_test, y_pred)
rf_model_recall = recall_score(y_test, y_pred)
rf_model_auc = roc_auc_score(y_test, y_pred)
rf_model_pre = precision_score(y_test, y_pred)
rf_model_recall_auc = auc(recall, precision)

# %%
train_val_rf = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_rf
# Out:
#             train_set  test_set
# Accuracy     1.000000  0.999501
# Precision    1.000000  1.000000
# Recall       1.000000  0.884211
# f1           1.000000  0.938547
# roc_auc      1.000000  0.942105
# recall_auc   0.942355  0.942355

# %% [markdown]
# ### *Cross Validation*

# %%
rf_model = RandomForestClassifier( class_weight="balanced", random_state = 42)
kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(rf_model, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.999569
# train_accuracy     0.999997
# test_precision     1.000000
# train_precision    1.000000
# test_recall        0.899502
# train_recall       0.999412
# test_f1            0.946110
# train_f1           0.999705
# test_roc_auc       0.989256
# train_roc_auc      1.000000
# dtype: float64

# %% [markdown]
# ## ***Tuned RF Model***

# %% [markdown]
# ### *GridSearch*

# %%
rf_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_model = RandomForestClassifier(class_weight = 'balanced', random_state = 42)

param_grid = {'n_estimators':[64, 100, 128, 200],
              'max_features':[3, 5, 'auto'],
              'max_depth':[4, 7, 9],
              'min_samples_split':[2, 5, 8]}


rf_model_grid = GridSearchCV(rf_model,
                             param_grid,
                             cv=5,
                             verbose=2,
                             scoring="recall",
                             n_jobs=-1,
                             return_train_score=True)

# %%
rf_model_grid.fit(X_train, y_train)

# %%
print('Best Params :', rf_model_grid.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', rf_model_grid.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
rf_model_grid = RandomForestClassifier(class_weight = 'balanced',
                                  max_depth = 5,
                                  max_features = 2,
                                  min_samples_split = 5,
                                  n_estimators = 50,
                                  random_state = 42)

rf_model_grid.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, max_features=2,
#                        min_samples_split=5, n_estimators=50, random_state=42)

# %%
eval_metric(rf_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21961     0]
#  [   12    83]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       1.00      0.87      0.93        95
#
#     accuracy                           1.00     22056
#    macro avg       1.00      0.94      0.97     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [   21   357]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      0.94      0.97       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      0.97      0.99     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = rf_model_grid.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
rf_model_grid = RandomForestClassifier(class_weight = 'balanced',
                                  max_depth = 5,
                                  max_features = 2,
                                  min_samples_split = 5,
                                  n_estimators = 50,
                                  random_state = 42)

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(rf_model_grid, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = rf_model_grid.predict(X_test)
y_train_pred = rf_model_grid.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


rf_model_grid_f1 = f1_score(y_test, y_pred)
rf_model_grid_acc = accuracy_score(y_test, y_pred)
rf_model_grid_recall = recall_score(y_test, y_pred)
rf_model_grid_auc = roc_auc_score(y_test, y_pred)
rf_model_grid_pre = precision_score(y_test, y_pred)
rf_model_grid_recall_auc = auc(recall, precision)

# %%
train_val_rf_grid = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_rf_grid
# Out:
#             train_set  test_set
# Accuracy     0.999762  0.999456
# Precision    1.000000  1.000000
# Recall       0.944444  0.873684
# f1           0.971429  0.932584
# roc_auc      0.972222  0.936842
# recall_auc   0.937114  0.937114

# %% [markdown]
# ## ***Feature-Importance***

# %%
rf_model_grid.feature_importances_
# Out:
# array([0.00125054, 0.03427427, 0.03780651, 0.08075255, 0.08384429,
#        0.01912717, 0.02525412, 0.03021079, 0.03450076, 0.04171444,
#        0.03877319, 0.07107477, 0.08693935, 0.00049289, 0.13054807,
#        0.00253782, 0.0444681 , 0.0793364 , 0.00517284, 0.0196133 ,
#        0.02332477, 0.0379934 , 0.00174088, 0.00668464, 0.00151783,
#        0.00372847, 0.00143716, 0.02054305, 0.01552867, 0.01980897])

# %%
rf_feature_imp = pd.DataFrame(data = rf_model_grid.feature_importances_, index=X.columns,
                              columns = ["Feature Importance"])

rf_feature_imp = rf_feature_imp.sort_values("Feature Importance", ascending = False)

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=rf_feature_imp["Feature Importance"], y=rf_feature_imp.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %% [markdown]
# # <p style="background-color:#367E18   ; font-family:newtimeroman; color:#191A19 ; font-size:125%; text-align:center; border-radius:10px 10px;">Random Forest Classifier with SMOTE<p>

# %% [markdown]
# ## ***Vanilla RF Model with Smote***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
X = df.drop(['Class'], axis = 1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y,
                                                     test_size = 0.2, random_state = 42)

# %%
print('X_train.shape : ', X_train.shape)
print('X_test.shape  : ', X_test.shape)
print('X_test.shape  : ', y_train.shape)
print('X_test.shape  : ', y_test.shape)
# Out:
# X_train.shape :  (88223, 30)
# X_test.shape  :  (22056, 30)
# X_test.shape  :  (88223,)
# X_test.shape  :  (22056,)

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

rf_model = RandomForestClassifier(random_state = 42)

rf_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("RF_Model" ,rf_model)])
rf_model_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('RF_Model', RandomForestClassifier(random_state=42))])

# %%
eval_metric(rf_model_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21960     1]
#  [    7    88]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       0.99      0.93      0.96        95
#
#     accuracy                           1.00     22056
#    macro avg       0.99      0.96      0.98     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [    0   378]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      1.00      1.00       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      1.00      1.00     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = rf_model_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

rf_model = RandomForestClassifier(random_state = 42)

rf_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("RF_Model" ,rf_model)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(rf_model_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = rf_model_smote.predict(X_test)
y_train_pred = rf_model_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


rf_model_smote_f1 = f1_score(y_test, y_pred)
rf_model_smote_acc = accuracy_score(y_test, y_pred)
rf_model_smote_recall = recall_score(y_test, y_pred)
rf_model_smote_auc = roc_auc_score(y_test, y_pred)
rf_model_smote_pre = precision_score(y_test, y_pred)
rf_model_smote_recall_auc = auc(recall, precision)

# %%
train_val_rf_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_rf_smote
# Out:
#             train_set  test_set
# Accuracy     1.000000  0.999637
# Precision    1.000000  0.988764
# Recall       1.000000  0.926316
# f1           1.000000  0.956522
# roc_auc      1.000000  0.963135
# recall_auc   0.957699  0.957699

# %% [markdown]
# ### *Cross Validation*

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
rf_model = RandomForestClassifier(random_state = 42)

rf_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("RF_Model" ,rf_model)])

kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(rf_model_smote, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.999887
# train_accuracy     0.999991
# test_precision     1.000000
# train_precision    0.997959
# test_recall        0.973613
# train_recall       1.000000
# test_f1            0.986485
# train_f1           0.998976
# test_roc_auc       0.992400
# train_roc_auc      1.000000
# dtype: float64

# %% [markdown]
# ## ***Tuned RF Model Smote***

# %% [markdown]
# ### *GridSearch*

# %%
rf_model_smote.get_params()
# Out:
# {'memory': None,
#  'steps': [('o', SMOTE(sampling_strategy={1: 10000})),
#   ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#   ('RF_Model', RandomForestClassifier(random_state=42))],
#  'verbose': False,
#  'o': SMOTE(sampling_strategy={1: 10000}),
#  'u': RandomUnderSampler(sampling_strategy={0: 30000}),
#  'RF_Model': RandomForestClassifier(random_state=42),
#  'o__k_neighbors': 5,
#  'o__n_jobs': None,
#  'o__random_state': None,
#  'o__sampling_strategy': {1: 10000},
#  'u__random_state': None,
#  'u__replacement': False,
#  'u__sampling_strategy': {0: 30000},
#  'RF_Model__bootstrap': True,
#  'RF_Model__ccp_alpha': 0.0,
#  'RF_Model__class_weight': None,
#  'RF_Model__criterion': 'gini',
#  'RF_Model__max_depth': None,
#  'RF_Model__max_features': 'sqrt',
#  'RF_Model__max_leaf_nodes': None,
#  'RF_Model__max_samples': None,
#  'RF_Model__min_impurity_decrease': 0.0,
#  'RF_Model__min_samples_leaf': 1,
#  'RF_Model__min_samples_split': 2,
# ...

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})
rf_model = RandomForestClassifier(random_state = 42)

rf_model_grid_smote = impipeline(steps=[('o', over),
                                        ('u', under),
                                        ("RF_Model" ,rf_model)])

param_grid = {'RF_Model__n_estimators':[64, 100, 128, 200],
              'RF_Model_max_features':[3, 5, 'auto'],
              'RF_Model_max_depth':[4, 7, 9],
              'RF_Model_min_samples_split':[2, 5, 8]}

kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

rf_model_grid_smote = GridSearchCV(rf_model_grid_smote,
                              param_grid,
                              verbose=3,
                              scoring="recall",
                              cv=kfold,
                              n_jobs=-1,
                              return_train_score=True)

# %%
rf_model_grid_smote.fit(X_train, y_train)

# %%
print('Best Params :', rf_model_grid_smote.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', rf_model_grid_smote.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

rf_model_grid_smote = RandomForestClassifier(max_depth = 5,
                                             max_features = 2,
                                             min_samples_split = 5,
                                             n_estimators = 50,
                                             random_state = 42)

rf_model_grid_smote = impipeline(steps=[('o', over),
                                        ('u', under),
                                        ("RF_Model" ,rf_model_grid_smote)])


rf_model_grid_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('RF_Model',
#                  RandomForestClassifier(max_depth=5, max_features=2,
#                                         min_samples_split=5, n_estimators=50,
#                                         random_state=42))])

# %%
eval_metric(rf_model_grid_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21961     0]
#  [   12    83]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       1.00      0.87      0.93        95
#
#     accuracy                           1.00     22056
#    macro avg       1.00      0.94      0.97     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [   28   350]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      0.93      0.96       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      0.96      0.98     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = rf_model_grid_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

rf_model_grid_smote = RandomForestClassifier(max_depth = 5,
                                             max_features = 2,
                                             min_samples_split = 5,
                                             n_estimators = 50,
                                             random_state = 42)

rf_model_grid_smote = impipeline(steps=[('o', over),
                                        ('u', under),
                                        ("RF_Model" ,rf_model_grid_smote)])
plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(rf_model_grid_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = rf_model_grid_smote.predict(X_test)
y_train_pred = rf_model_grid_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


rf_model_grid_smote_f1 = f1_score(y_test, y_pred)
rf_model_grid_smote_acc = accuracy_score(y_test, y_pred)
rf_model_grid_smote_recall = recall_score(y_test, y_pred)
rf_model_grid_smote_auc = roc_auc_score(y_test, y_pred)
rf_model_grid_smote_pre = precision_score(y_test, y_pred)
rf_model_grid_smote_recall_auc = auc(recall, precision)

# %%
train_val_rf_grid_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_rf_grid_smote
# Out:
#             train_set  test_set
# Accuracy     0.999705  0.999501
# Precision    1.000000  1.000000
# Recall       0.931217  0.884211
# f1           0.964384  0.938547
# roc_auc      0.965608  0.942105
# recall_auc   0.942355  0.942355

# %% [markdown]
# ## ***Feature-Importance-Smote***

# %%
rf_feature_imp_smote = pd.DataFrame(data = rf_model_grid_smote["RF_Model"].feature_importances_, index=X.columns,
                              columns = ["Feature Importance"])

rf_feature_imp_smote = rf_feature_imp_smote.sort_values("Feature Importance", ascending = False)

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=rf_feature_imp_smote["Feature Importance"], y=rf_feature_imp_smote.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#191A19 ;font-weight: normal; font-size:125%; text-align:center; border-radius:10px 10px;">XGB Classifier without SMOTE<p>

# %% [markdown]
# ## ***Vanilla XGB Model***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42)

# %%
xgb_model = XGBClassifier(random_state = 42)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
eval_metric(xgb_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21961     0]
#  [    8    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       1.00      0.92      0.96        95
#
#     accuracy                           1.00     22056
#    macro avg       1.00      0.96      0.98     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [    0   378]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      1.00      1.00       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      1.00      1.00     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = xgb_model.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
xgb_model = XGBClassifier(random_state = 42)
xgb_model.fit(X_train, y_train)

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(xgb_model, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = xgb_model.predict(X_test)
y_train_pred = xgb_model.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


xgb_model_f1 = f1_score(y_test, y_pred)
xgb_model_acc = accuracy_score(y_test, y_pred)
xgb_model_recall = recall_score(y_test, y_pred)
xgb_model_auc = roc_auc_score(y_test, y_pred)
xgb_model_pre = precision_score(y_test, y_pred)
xgb_model_recall_auc = auc(recall, precision)

# %%
train_val_xgb = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_xgb
# Out:
#             train_set  test_set
# Accuracy     1.000000  0.999637
# Precision    1.000000  1.000000
# Recall       1.000000  0.915789
# f1           1.000000  0.956044
# roc_auc      1.000000  0.957895
# recall_auc   0.958076  0.958076

# %% [markdown]
# ### *Cross Validation*

# %%
xgb_model = XGBClassifier(random_state = 42)
kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(xgb_model, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.999701
# train_accuracy     1.000000
# test_precision     1.000000
# train_precision    1.000000
# test_recall        0.930427
# train_recall       1.000000
# test_f1            0.963263
# train_f1           1.000000
# test_roc_auc       0.989885
# train_roc_auc      1.000000
# dtype: float64

# %% [markdown]
# ## ***Tuned XGB Model***

# %% [markdown]
# ### *GridSearch*

# %%
xgb_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
# ...

# %%
xgb_model = XGBClassifier(random_state = 42)

param_grid = {"n_estimators": [50, 100],
              'max_depth': [3, 5],
              "learning_rate": [0.1, 0.2],
              "subsample": [0.8, 1],
              "colsample_bytree": [0.8, 1]}



xgb_model_grid = GridSearchCV(xgb_model,
                              param_grid,
                              verbose=3,
                              scoring="recall",
                              cv=5,
                              n_jobs=-1,
                              return_train_score=True)

# %%
xgb_model_grid.fit(X_train, y_train)

# %%
print('Best Params :', xgb_model_grid.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', xgb_model_grid.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
xgb_model_grid = XGBClassifier(colsample_bytree=0.8,
                               learning_rate=0.1,
                               max_depth=3,
                               n_estimators=50,
                               random_state=42,
                               subsample=0.8)

xgb_model_grid.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
eval_metric(xgb_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21961     0]
#  [    8    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       1.00      0.92      0.96        95
#
#     accuracy                           1.00     22056
#    macro avg       1.00      0.96      0.98     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87845     0]
#  [   18   360]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      0.95      0.98       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      0.98      0.99     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = xgb_model_grid.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
xgb_model_grid = XGBClassifier(colsample_bytree=0.8,
                               learning_rate=0.1,
                               max_depth=3,
                               n_estimators=50,
                               random_state=42,
                               subsample=0.8)

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(xgb_model_grid, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = xgb_model_grid.predict(X_test)
y_train_pred = xgb_model_grid.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


xgb_model_grid_f1 = f1_score(y_test, y_pred)
xgb_model_grid_acc = accuracy_score(y_test, y_pred)
xgb_model_grid_recall = recall_score(y_test, y_pred)
xgb_model_grid_auc = roc_auc_score(y_test, y_pred)
xgb_model_grid_pre = precision_score(y_test, y_pred)
xgb_model_grid_recall_auc = auc(recall, precision)

# %%
train_val_xgb_grid = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_xgb_grid
# Out:
#             train_set  test_set
# Accuracy     0.999796  0.999637
# Precision    1.000000  1.000000
# Recall       0.952381  0.915789
# f1           0.975610  0.956044
# roc_auc      0.976190  0.957895
# recall_auc   0.958076  0.958076

# %% [markdown]
# ## ***Feature-Importance***

# %%
xgb_feature_imp = pd.DataFrame(data = xgb_model_grid.feature_importances_, index=X.columns,
                              columns = ["Feature Importance"])

xgb_feature_imp = xgb_feature_imp.sort_values("Feature Importance", ascending = False)

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=xgb_feature_imp["Feature Importance"], y=xgb_feature_imp.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %% [markdown]
# # <p style="background-color:#367E18   ; font-family:newtimeroman; color:#191A19 ; font-size:125%; text-align:center; border-radius:10px 10px;">XGB Classifier with SMOTE<p>

# %% [markdown]
# ## ***Vanilla XGB Model with Smote***

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y,
                                                     test_size = 0.2, random_state = 42)

# %%
print('X_train.shape : ', X_train.shape)
print('X_test.shape  : ', X_test.shape)
print('X_test.shape  : ', y_train.shape)
print('X_test.shape  : ', y_test.shape)
# Out:
# X_train.shape :  (88223, 30)
# X_test.shape  :  (22056, 30)
# X_test.shape  :  (88223,)
# X_test.shape  :  (22056,)

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model = XGBClassifier(random_state = 42)

xgb_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("XGB_Model" ,xgb_model)])
xgb_model_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('XGB_Model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, gp...one,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %%
eval_metric(xgb_model_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21959     2]
#  [    7    88]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       0.98      0.93      0.95        95
#
#     accuracy                           1.00     22056
#    macro avg       0.99      0.96      0.98     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87844     1]
#  [    0   378]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       1.00      1.00      1.00       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      1.00      1.00     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = xgb_model_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model = XGBClassifier(random_state = 42)

xgb_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("XGB_Model" ,xgb_model)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(xgb_model_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Vanilla*

# %%
y_pred = xgb_model_smote.predict(X_test)
y_train_pred = xgb_model_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


xgb_model_smote_f1 = f1_score(y_test, y_pred)
xgb_model_smote_acc = accuracy_score(y_test, y_pred)
xgb_model_smote_recall = recall_score(y_test, y_pred)
xgb_model_smote_auc = roc_auc_score(y_test, y_pred)
xgb_model_smote_pre = precision_score(y_test, y_pred)
xgb_model_smote_recall_auc = auc(recall, precision)

# %%
train_val_xgb_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_xgb_smote
# Out:
#             train_set  test_set
# Accuracy     0.999966  0.999637
# Precision    0.992126  0.988764
# Recall       1.000000  0.926316
# f1           0.996047  0.956522
# roc_auc      0.999983  0.963135
# recall_auc   0.957699  0.957699

# %% [markdown]
# ### *Cross Validation*

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model = XGBClassifier(random_state = 42)

xgb_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("XGB_Model" ,xgb_model)])

kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

scores = cross_validate(xgb_model_smote, X_train, y_train, 
                        scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                        cv=kfold, return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_accuracy      0.999728
# train_accuracy     0.999975
# test_precision     0.989399
# train_precision    0.994178
# test_recall        0.947155
# train_recall       1.000000
# test_f1            0.967135
# train_f1           0.997074
# test_roc_auc       0.993550
# train_roc_auc      1.000000
# dtype: float64

# %% [markdown]
# ## ***Tuned RF Model Smote***

# %% [markdown]
# ### *GridSearch*

# %%
xgb_model_smote.get_params()
# Out:
# {'memory': None,
#  'steps': [('o', SMOTE(sampling_strategy={1: 10000})),
#   ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#   ('XGB_Model',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric=None, feature_types=None,
#                  gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  predictor=None, random_state=42, ...))],
#  'verbose': False,
# ...

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model = XGBClassifier(random_state = 42)

xgb_model_smote = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("XGB_Model" ,xgb_model)])

param_grid = {"n_estimators": [50, 100],
              'max_depth': [3, 5],
              "learning_rate": [0.1, 0.2],
              "subsample": [0.8, 1],
              "colsample_bytree": [0.8, 1]}

xgb_model_grid_smote = GridSearchCV(xgb_model_smote,
                              param_grid,
                              verbose=3,
                              scoring="recall",
                              cv=5,
                              n_jobs=-1,
                              return_train_score=True)

# %%
xgb_model_grid_smote.fit(X_train, y_train)

# %%
print('Best Params :', xgb_model_grid_smote.best_params_)
# Out:
# Best Params : {'LogReg__class_weight': None, 'LogReg__penalty': 'l2', 'LogReg__solver': 'lbfgs'}

# %%
print('Best Score :', xgb_model_grid_smote.best_score_)
# Out:
# Best Score : 0.9624656711265638

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model_grid = XGBClassifier(colsample_bytree=0.8,
                               learning_rate=0.1,
                               max_depth=3,
                               n_estimators=50,
                               random_state=42,
                               subsample=0.8)

xgb_model_grid_smote = impipeline(steps=[('o', over),
                                         ('u', under),
                                         ("XGB_Model" ,xgb_model_grid)])


xgb_model_grid_smote.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={1: 10000})),
#                 ('u', RandomUnderSampler(sampling_strategy={0: 30000})),
#                 ('XGB_Model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.8, early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=3, max_leaves=None,
# ...

# %%
eval_metric(xgb_model_grid_smote, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[21960     1]
#  [    7    88]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21961
#            1       0.99      0.93      0.96        95
#
#     accuracy                           1.00     22056
#    macro avg       0.99      0.96      0.98     22056
# weighted avg       1.00      1.00      1.00     22056
#
#
# Train_Set
# [[87842     3]
#  [   14   364]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     87845
#            1       0.99      0.96      0.98       378
#
#     accuracy                           1.00     88223
#    macro avg       1.00      0.98      0.99     88223
# weighted avg       1.00      1.00      1.00     88223

# %%
plt.figure(figsize=(10,6))

y_pred = xgb_model_grid_smote.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
over = SMOTE(sampling_strategy = {1: 10000})
under = RandomUnderSampler(sampling_strategy = {0: 30000})

xgb_model_grid = XGBClassifier(colsample_bytree=0.8,
                               learning_rate=0.1,
                               max_depth=3,
                               n_estimators=50,
                               random_state=42,
                               subsample=0.8)

xgb_model_grid_smote = impipeline(steps=[('o', over),
                                         ('u', under),
                                         ("XGB_Model" ,xgb_model_grid)])

plt.figure(figsize=(10,6))
viz = PrecisionRecallCurve(xgb_model_grid_smote, cmap="Set1")
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ### *Scores-Grid*

# %%
y_pred = xgb_model_grid_smote.predict(X_test)
y_train_pred = xgb_model_grid_smote.predict(X_train)
precision, recall, _ = precision_recall_curve(y_test, y_pred)


xgb_model_grid_smote_f1 = f1_score(y_test, y_pred)
xgb_model_grid_smote_acc = accuracy_score(y_test, y_pred)
xgb_model_grid_smote_recall = recall_score(y_test, y_pred)
xgb_model_grid_smote_auc = roc_auc_score(y_test, y_pred)
xgb_model_grid_smote_pre = precision_score(y_test, y_pred)
xgb_model_grid_smote_recall_auc = auc(recall, precision)

# %%
train_val_xgb_grid_smote = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_xgb_grid_smote
# Out:
#             train_set  test_set
# Accuracy     0.999819  0.999683
# Precision    0.991848  1.000000
# Recall       0.965608  0.926316
# f1           0.978552  0.961749
# roc_auc      0.982787  0.963158
# recall_auc   0.963317  0.963317

# %% [markdown]
# ## ***Feature-Importance-Smote***

# %%
xgb_feature_imp_smote = pd.DataFrame(data = xgb_model_grid_smote["XGB_Model"].feature_importances_, index=X.columns,
                              columns = ["Feature Importance"])

xgb_feature_imp_smote = xgb_feature_imp_smote.sort_values("Feature Importance", ascending = False)

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=xgb_feature_imp_smote["Feature Importance"], y=xgb_feature_imp_smote.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %% [markdown]
# # <p style="background-color:#367E18 ; font-family:newtimeroman; color:#191A19 ;font-weight: normal; font-size:125%; text-align:center; border-radius:10px 10px;">ANN Classifier<p>

# %% [markdown]
# ### İmport

# %%
## ann
import tensorflow as tf
from sklearn.neural_network import MLPRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, Nadam, SGD, Adamax, RMSprop,Adadelta, Adagrad
from tensorflow.keras.layers import Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# from scikeras.wrappers import KerasClassifier, KerasRegressor
# from sikeras.callbacks import EarlyStopping

from sklearn.utils import class_weight
from sklearn.utils import compute_class_weight

# %% [markdown]
# ## ***Vanilla ANN Model***

# %%
df = pd.read_csv("https://drive.google.com/file/d/1ZqXsdgkPrQnVRr4wMKVTQqgeO-2VJ04A")
df.sample(5)
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 26461   68304.0 -1.766173 -0.684528  1.751738 -0.595347  1.016007  0.213043
# 36433  140994.0  2.113442  0.050843 -1.500615  0.268930  0.634220 -0.296820
# 20245   71756.0  1.166074  0.227870  0.710003  0.697481 -0.517717 -0.813669
# 51202  170249.0  2.171575 -0.733277 -1.130880 -0.616075 -0.246593 -0.029435
# 76058  171282.0  1.906049 -0.685516 -0.378718  0.307020 -0.690906  0.177261
#
#              V7        V8        V9       V10       V11       V12       V13  \
# 26461  0.061933  0.226837  0.228593 -0.877384 -0.329475  1.099126  0.823933
# 36433  0.223754 -0.262514  0.347780  0.049965 -1.215547  0.877166  1.574211
# 20245  0.037547 -0.130195 -0.068525 -0.128027  0.563483  0.885173  0.682067
# 51202 -0.574152 -0.184870 -0.378750  0.793015 -1.479256  0.607239  2.130745
# 76058 -0.904684  0.288684  1.219483  0.197167  0.512724  0.223246 -1.454883
#
# ...

# %% [markdown]
# ### *Model Build, Train & Pred*

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,
                                                    test_size=0.1,
                                                    random_state=42)

# %%
print('X_train.shape:', X_train.shape)
print('y_train.shape:', y_train.shape)
print('X_test.shape:', X_test.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (99251, 30)
# y_train.shape: (99251,)
# X_test.shape: (11028, 30)
# y_test.shape: (11028,)

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### *Without class_weigth*

# %%
tf.random.set_seed(42)

ann_model = Sequential()

ann_model.add(Dense(60, activation = "relu", input_dim = X_train.shape[1]))
ann_model.add(Dense(30, activation = "relu"))
ann_model.add(Dense(15, activation = "relu"))
ann_model.add(Dense(5, activation = "relu"))
ann_model.add(Dense(1, activation = "sigmoid"))

opt = Adam(learning_rate=0.001) # optimizer 
ann_model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
early_stop = EarlyStopping(monitor = "val_loss",
                           mode = "min",
                           verbose = 1,
                           patience = 15,
                           restore_best_weights = True)

# %%
ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 60)                1860
#
#  dense_1 (Dense)             (None, 30)                1830
#
#  dense_2 (Dense)             (None, 15)                465
#
#  dense_3 (Dense)             (None, 5)                 80
#
#  dense_4 (Dense)             (None, 1)                 6
#
# ...
# Total params: 4,241
# Trainable params: 4,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann_model.fit(x = X_train, y = y_train,
        validation_split = 0.1,
        batch_size = 32, epochs = 200,
        verbose = 1,
        callbacks=[early_stop, PlotLossesKerasTF()])
# Out:
# Loss
# 	training         	 (min:    0.001, max:    0.012, cur:    0.001)
# 	validation       	 (min:    0.002, max:    0.010, cur:    0.006)
# recall
# 	training         	 (min:    0.817, max:    0.974, cur:    0.974)
# 	validation       	 (min:    0.897, max:    0.923, cur:    0.897)
# 2792/2792 [==============================] - 9s 3ms/step - loss: 5.2867e-04 - recall: 0.9742 - val_loss: 0.0065 - val_recall: 0.8974
# Epoch 19: early stopping

# %% [markdown]
# #### Evaluating Model Performance and Tunning

# %%
plt.rcParams["figure.figsize"] = (12,8)

# %%
loss_df = pd.DataFrame(ann_model.history.history) 
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (ann_model.predict(X_test) > .5).astype("int32") 
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 345/345 [==============================] - 1s 2ms/step
# [[10981     0]
#  [    4    43]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10981
#            1       1.00      0.91      0.96        47
#
#     accuracy                           1.00     11028
#    macro avg       1.00      0.96      0.98     11028
# weighted avg       1.00      1.00      1.00     11028

# %%
plt.figure(figsize=(10,6))

cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
y_pred_proba = ann_model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 345/345 [==============================] - 1s 2ms/step

# %%
non_weighted_pre_score = average_precision_score(y_test, y_pred_proba)
non_weighted_pre_score
# Out:
# 0.9266296714377803

# %%
non_weighted_f1 = f1_score(y_test, y_pred)
non_weighted_recall = recall_score(y_test, y_pred)

# %% [markdown]
# ### *With class_weigth*

# %%
tf.random.set_seed(42)

ann_model_weight = Sequential()

ann_model_weight.add(Dense(36, activation = "relu", input_dim = X_train.shape[1]))
ann_model_weight.add(Dense(18, activation = "relu"))
ann_model_weight.add(Dense(9, activation = "relu"))
ann_model_weight.add(Dense(1, activation = "sigmoid"))

opt = Adam(learning_rate=0.001) # optimizer 
ann_model_weight.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.5021553250695674, 1: 116.49178403755869}

# %%
ann_model_weight.fit(x = X_train, y = y_train,
        validation_split = 0.1,
        batch_size = 32, epochs = 200,
        verbose = 1,
        callbacks=[early_stop, PlotLossesKerasTF()],
        class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.014, max:    0.338, cur:    0.030)
# 	validation       	 (min:    0.007, max:    0.115, cur:    0.047)
# recall
# 	training         	 (min:    0.891, max:    0.995, cur:    0.990)
# 	validation       	 (min:    0.897, max:    0.949, cur:    0.923)
# 2792/2792 [==============================] - 19s 7ms/step - loss: 0.0300 - recall: 0.9897 - val_loss: 0.0474 - val_recall: 0.9231
# Epoch 23: early stopping

# %%
loss_df = pd.DataFrame(ann_model_weight.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (ann_model_weight.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 345/345 [==============================] - 1s 2ms/step
# [[10962    19]
#  [    4    43]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10981
#            1       0.69      0.91      0.79        47
#
#     accuracy                           1.00     11028
#    macro avg       0.85      0.96      0.89     11028
# weighted avg       1.00      1.00      1.00     11028

# %%
y_pred_proba = ann_model_weight.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 345/345 [==============================] - 1s 3ms/step

# %%
weighted_pre_score = average_precision_score(y_test, y_pred_proba)
weighted_pre_score
# Out:
# 0.9217445739461256

# %%
weighted_f1 = f1_score(y_test, y_pred)
weighted_recall = recall_score(y_test, y_pred)

# %%
loss, recall = ann_model_weight.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.008575760759413242
# recall :  0.914893627166748

# %% [markdown]
# ## ***Tuned ANN Model***

# %% [markdown]
# ### *GridSearch*

# %%
def build_classifier(optimizer, learn_rate):
    tf.random.set_seed(42)
    classifier = Sequential()
    classifier.add(Dense(units=36, activation='relu'))
    classifier.add(Dense(units=18, activation='relu'))
    classifier.add(Dense(units=9, activation='relu'))
    classifier.add(Dense(units=1, activation='sigmoid'))
    classifier.compile(optimizer=optimizer(learn_rate),
                       loss='binary_crossentropy',
                       metrics=['Recall'])
    return classifier

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="min",
                           verbose=1,
                           patience=15,
                           restore_best_weights=True)

# %%
# pip install scikeras[tensorflow]
# Out:
# ...
#
# ...
#      ------------------------------------ 266.3/266.3 MB 963.6 kB/s eta 0:00:00
# ...
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# ...
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# ...
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.10.0
#     Uninstalling tensorflow-estimator-2.10.0:
#       Successfully uninstalled tensorflow-estimator-2.10.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Uninstalling keras-2.10.0:
#       Successfully uninstalled keras-2.10.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.10.1
#     Uninstalling tensorboard-2.10.1:
#       Successfully uninstalled tensorboard-2.10.1
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\mhsna\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
# ...

# %%
# from scikeras.wrappers import KerasClassifier, KerasRegressor

# %%
classifier_model = KerasClassifier(build_fn=build_classifier, validation_split=0.1, epochs=200)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, Adadelta, RMSprop, Nadam, Adagrad, SGD],
              'learn_rate': [0.001, 0.003, 0.005]}

ann_model_grid = GridSearchCV(estimator=classifier_model,
                          param_grid=parameters,
                          scoring='recall',
                          cv=10,
                          n_jobs=-1,
                          verbose=1)
# Out:
# <ipython-input-144-f3b6e3e0ee82>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier_model = KerasClassifier(build_fn=build_classifier, validation_split=0.1, epochs=200)

# %%
ann_model_grid.fit(X_train,
               y_train,
               callbacks=[early_stop],
               class_weight = {0: 0.5021553250695674, 1: 116.49178403755869})

# %%
ann_model_grid.best_score_

# %%
ann_model_grid.best_params_

# %%
y_pred = (ann_model_grid.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
ann_model_grid = Sequential()

ann_model_grid.add(Dense(32, activation = "relu"))
ann_model_grid.add(Dropout(0.25))
ann_model_grid.add(Dense(16, activation = "relu"))
ann_model_grid.add(Dropout(0.25))
ann_model_grid.add(Dense(1, activation = "sigmoid"))

optimizer = SGD(learning_rate= 0.001)
ann_model_grid.compile(loss = 'binary_crossentropy',
                 optimizer = optimizer,
                 metrics = ["Recall"])

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.5021553250695674, 1: 116.49178403755869}

# %%
ann_model_grid.fit(x = X_train, y = y_train,
        validation_split = 0.1,
        batch_size = 64, epochs = 500,
        verbose = 0,
        callbacks=[early_stop, PlotLossesKerasTF()],
        class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.033, max:    0.514, cur:    0.037)
# 	validation       	 (min:    0.016, max:    0.634, cur:    0.018)
# recall
# 	training         	 (min:    0.871, max:    0.992, cur:    0.977)
# 	validation       	 (min:    0.897, max:    0.974, cur:    0.923)
# Epoch 119: early stopping

# %%
loss_df = pd.DataFrame(ann_model_grid.history.history) 
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (ann_model_grid.predict(X_test) > .5).astype("int32") 
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 345/345 [==============================] - 1s 2ms/step
# [[10952    29]
#  [    4    43]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10981
#            1       0.60      0.91      0.72        47
#
#     accuracy                           1.00     11028
#    macro avg       0.80      0.96      0.86     11028
# weighted avg       1.00      1.00      1.00     11028

# %%
plt.figure(figsize=(10,6))

cf_matrix = confusion_matrix(y_test, y_pred)

group_names = ['True Negatives (TN)', 'False Positives (FP)\n(Type I Error)', 
               'False Negatives (FN)\n(Type II Error)', 'True Positives (TP)']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]

labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cf_matrix, annot=labels, fmt="", annot_kws={'size': 13}, cmap='PRGn', vmax=220)
ax.set(xlabel='Predicted Class', ylabel = 'Actual Class');

# %%
y_pred_proba = ann_model_grid.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 345/345 [==============================] - 1s 2ms/step

# %%
grid_pre_score = average_precision_score(y_test, y_pred_proba)
grid_pre_score
# Out:
# 0.9248836411632315

# %%
grid_weighted_f1 = f1_score(y_test, y_pred)
grid_weighted_recall = recall_score(y_test, y_pred)

# %% [markdown]
# ## ANN_Model Comparission

# %%
compare = pd.DataFrame({
    "Model": ["ANN", "ANN_Weighted", "ANN_Tuned"],
    "F1": [non_weighted_f1, weighted_f1, grid_weighted_f1],
    "Recall": [non_weighted_recall, weighted_recall, grid_weighted_recall],
    "Avg_Precision": [non_weighted_pre_score, weighted_pre_score, grid_pre_score]
})


def labels(ax):
    for p in ax.patches:
        width = p.get_width()  # get bar length
        ax.text(
            width,  # set the text at 1 unit right of the bar
            p.get_y() +
            p.get_height() / 2,  # get Y coordinate + X coordinate / 2
            '{:1.3f}'.format(width),  # set variable to display, 2 decimals
            ha='left',  # horizontal alignment
            va='center')  # vertical alignment


plt.figure(figsize=(14, 10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax = sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax = sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="Avg_Precision", ascending=False)
ax = sns.barplot(x="Avg_Precision", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %%
# Ann_Weighted Seçtik(Recall(1))

# %% [markdown]
# ## ANN Final Model and Export

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.1, random_state=42)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
pickle.dump(scaler, open("scaler.pkl", "wb"))

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
tf.random.set_seed(42)

final_model_ann = Sequential()

final_model_ann.add(Dense(36, activation = "relu", input_dim = X_train.shape[1]))
final_model_ann.add(Dense(18, activation = "relu"))
final_model_ann.add(Dense(9, activation = "relu"))
final_model_ann.add(Dense(1, activation = "sigmoid"))

opt = Adam(learning_rate=0.001) # optimizer 
final_model_ann.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
class_weights
# Out:
# {0: 0.5021553250695674, 1: 116.49178403755869}

# %%
final_model_ann.fit(x = X_train, y = y_train,
        validation_split = 0.1,
        batch_size = 32, epochs = 200,
        verbose = 1,
        callbacks=[early_stop, PlotLossesKerasTF()],
        class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.098, max:    0.378, cur:    0.111)
# 	validation       	 (min:    0.007, max:    0.731, cur:    0.038)
# recall
# 	training         	 (min:    0.739, max:    0.956, cur:    0.948)
# 	validation       	 (min:    0.846, max:    0.974, cur:    0.923)
# 2792/2792 [==============================] - 18s 7ms/step - loss: 0.1112 - recall: 0.9483 - val_loss: 0.0379 - val_recall: 0.9231
# Epoch 37: early stopping

# %%
loss_df = pd.DataFrame(final_model_ann.history.history)
loss_df.plot()

# %%
y_pred = (final_model_ann.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 345/345 [==============================] - 2s 5ms/step
# [[10979     2]
#  [    5    42]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10981
#            1       0.95      0.89      0.92        47
#
#     accuracy                           1.00     11028
#    macro avg       0.98      0.95      0.96     11028
# weighted avg       1.00      1.00      1.00     11028

# %%
final_model_ann.save('model_ANN.h5')

# %% [markdown]
# ### Scores

# %%
y_pred = (final_model_ann.predict(X_test) > 0.5).astype("int32")
y_train_pred = (final_model_ann.predict(X_train) > 0.5).astype("int32")
precision, recall, _ = precision_recall_curve(y_test, y_pred)


final_model_ann_f1 = f1_score(y_test, y_pred)
final_model_ann_acc = final_model_ann.evaluate(X_test, y_test, verbose=0)[1]
final_model_ann_recall = recall_score(y_test, y_pred)
final_model_ann_auc = roc_auc_score(y_test, y_pred)
final_model_ann_pre = precision_score(y_test, y_pred)
final_model_ann_recall_auc = auc(recall, precision)
# Out:
# ...
# 3102/3102 [==============================] - 16s 5ms/step

# %%
train_val_ann = train_val(y_train, y_train_pred, y_test, y_pred)
train_val_ann
# Out:
#             train_set  test_set
# Accuracy     0.999597  0.999365
# Precision    0.982500  0.954545
# Recall       0.922535  0.893617
# f1           0.951574  0.923077
# roc_auc      0.961232  0.946717
# recall_auc   0.924308  0.924308

# %% [markdown]
# ## Prediction

# %%
model_ANN = load_model('model_ANN.h5')
scaler = pickle.load(open("scaler.pkl", "rb"))

# %%
test = df.sample(8)
test.T

# %%
test = scaler.transform(test)

# %%
(model_ANN.predict(test) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 79ms/step
# array([[0]])

# %%
model_ANN.predict(test)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[0.10928454]], dtype=float32)

# %% [markdown]
# # <p style="background-color:#183A1D ; font-family:newtimeroman; color:#FFE9A0 ;font-weight: normal; font-size:125%; text-align:center; border-radius:10px 10px;">Model Compare<p>
# <!-- DA0037, EDEDED -->

# %% [markdown]
# ## Compare-1

# %%
compare = pd.DataFrame({"Model": ["LogReg_Model", "LogReg_Grid", "LogReg_Model_Smote", "LogReg_Grid_Smote",
                                  "RF_Model", "RF_Grid", "RF_Model_Smote", "RF_Grid_Smote",
                                  "XGB_Model", "XGB_Grid", "XGB_Model_Smote", "XGB_Grid_Smote",
                                  "ANN_Model"],
                        
                        
                        "Recall_Score": [log_model_recall, log_model_grid_recall, log_model_smote_recall, log_model_grid_smote_recall,
                                           rf_model_recall, rf_model_grid_recall, rf_model_smote_recall, rf_model_grid_smote_recall,
                                           xgb_model_recall, xgb_model_grid_recall, xgb_model_smote_recall, xgb_model_grid_smote_recall,
                                           final_model_ann_recall],
                        
                        "F1_Score": [log_model_f1, log_model_grid_f1, log_model_smote_f1, log_model_grid_smote_f1,
                                           rf_model_f1, rf_model_grid_f1, rf_model_smote_f1, rf_model_grid_smote_f1,
                                           xgb_model_f1, xgb_model_grid_f1, xgb_model_smote_f1, xgb_model_grid_smote_f1,
                                           final_model_ann_f1],
                        
                        "Recall_Auc_Score": [log_model_recall_auc, log_model_grid_recall_auc, log_model_smote_recall_auc, log_model_grid_smote_recall_auc,
                                           rf_model_recall_auc, rf_model_grid_recall_auc, rf_model_smote_recall_auc, rf_model_grid_smote_recall_auc,
                                           xgb_model_recall_auc, xgb_model_grid_recall_auc, xgb_model_smote_recall_auc, xgb_model_grid_smote_recall_auc,
                                           final_model_ann_recall_auc],
                        
                        "Roc_Auc_Score": [log_model_auc, log_model_grid_auc, log_model_smote_auc, log_model_grid_smote_auc,
                                           rf_model_auc, rf_model_grid_auc, rf_model_smote_auc, rf_model_grid_smote_auc,
                                           xgb_model_auc, xgb_model_grid_auc, xgb_model_smote_auc, xgb_model_grid_smote_auc,
                                           final_model_ann_auc],
                        
                        "Precision_Score": [log_model_pre, log_model_grid_pre, log_model_smote_pre, log_model_grid_smote_pre,
                                           rf_model_pre, rf_model_grid_pre, rf_model_smote_pre, rf_model_grid_smote_pre,
                                           xgb_model_pre, xgb_model_grid_pre, xgb_model_smote_pre, xgb_model_grid_smote_pre,
                                           final_model_ann_pre],
                        
                        "Accuracy_Score": [log_model_acc, log_model_grid_acc, log_model_smote_acc, log_model_grid_smote_acc,
                                           rf_model_acc, rf_model_grid_acc, rf_model_smote_acc, rf_model_grid_smote_acc,
                                           xgb_model_acc, xgb_model_grid_acc, xgb_model_smote_acc, xgb_model_grid_smote_acc,
                                           final_model_ann_acc]
                        
                        })

# %%
compare
# Out:
#                  Model  Recall_Score  Precision_Score  Recall_Auc_Score  \
# 0         LogReg_Model      0.929577         0.352941          0.641410
# 1          LogReg_Grid      0.929577         0.352941          0.641410
# 2   LogReg_Model_Smote      0.915789         0.587838          0.751995
# 3    LogReg_Grid_Smote      0.915789         0.580000          0.748076
# 4             RF_Model      0.884211         1.000000          0.942355
# 5              RF_Grid      0.873684         1.000000          0.937114
# 6       RF_Model_Smote      0.926316         0.988764          0.957699
# 7        RF_Grid_Smote      0.884211         1.000000          0.942355
# 8            XGB_Model      0.915789         1.000000          0.958076
# 9             XGB_Grid      0.915789         1.000000          0.958076
# 10     XGB_Model_Smote      0.915789         0.988636          0.952394
# 11      XGB_Grid_Smote      0.926316         0.977778          0.952205
# ...

# %%
plt.figure(figsize=(14,28))

index = 0

for col in compare.iloc[:, 1:].columns:    
    index += 1
    plt.subplot(6,1,index)
    a = sns.barplot(data=compare.sort_values(col, ascending=False), x='Model', y=col, palette="PRGn")
    a.bar_label(a.containers[0], fmt='%.3f', fontsize=15, fontweight='bold'), plt.ylim(0, 1.2)
    plt.title(f'Distribution of {col} Scores', fontsize=20, fontweight='bold', pad=10)
    plt.xticks(rotation = 45)
plt.tight_layout()

# %% [markdown]
# ## Compare-2

# %%
import plotly.express as px

# %%
compare = compare.sort_values(by="Recall_Score", ascending=True)
fig = px.bar(compare, x = "Recall_Score", y = "Model", title = "Recall_Score")
fig.show()

compare = compare.sort_values(by="F1_Score", ascending=True)
fig = px.bar(compare, x = "F1_Score", y = "Model", title = "F1_Score")
fig.show()

compare = compare.sort_values(by="Roc_Auc_Score", ascending=True)
fig = px.bar(compare, x = "Roc_Auc_Score", y = "Model", title = "Roc_Auc_Score")
fig.show()

compare = compare.sort_values(by="Recall_Auc_Score", ascending=True)
fig = px.bar(compare, x = "Recall_Auc_Score", y = "Model", title = "Recall_Auc_Score")
fig.show()

compare = compare.sort_values(by="Precision_Score", ascending=True)
fig = px.bar(compare, x = "Precision_Score", y = "Model", title = "Precision_Score")
fig.show()

compare = compare.sort_values(by="Accuracy_Score", ascending=True)
fig = px.bar(compare, x = "Accuracy_Score", y = "Model", title = "Accuracy_Score")
fig.show()

# %% [markdown]
# ## 4. Model Deployement
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to a proper IDE and create your web app with Streamlit API.

# %% [markdown]
# ### Save and Export the Best Model

# %% [markdown]
# ### Logistic Regression

# %%
scaler = StandardScaler()
LogReg = LogisticRegression(class_weight = 'balanced', random_state = 42, max_iter=1000)
log_model_final = Pipeline(steps=[("StandardScaler", scaler), ("LogReg" ,LogReg)])
log_model_final.fit(X, y)

# %%
pickle.dump(log_model_final, open("model_LOG.pkl", "wb"))

# %% [markdown]
# ### XGB

# %%
print('X.shape : ', X.shape)
print('y.shape  : ', y.shape)

# %%
over = SMOTE(sampling_strategy = {1: 50000})
under = RandomUnderSampler(sampling_strategy = {0: 20000})

xgb_model_final = XGBClassifier(random_state = 42)

xgb_model_smote_final = impipeline(steps=[('o', over),
                                    ('u', under),
                                    ("XGB_Model" ,xgb_model_final)])
xgb_model_smote_final.fit(X, y)

# %%
pickle.dump(xgb_model_smote_final, open("model_smote_XGB.pkl", "wb"))

# %% [markdown]
# ### Save and Export Variables

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
